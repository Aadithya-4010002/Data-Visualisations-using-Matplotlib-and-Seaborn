# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/Users/aadithyaram/Downloads/dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0                track_id           artists  \
# 113995      113995  2C3TZjDRiAzdyViavDJ217     Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw     Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX     Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs  Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5     Cesária Evora
#
#                                                album_name  \
# 113995  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997                                            Best Of
# 113998                                  Change Your World
# 113999                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# ...

# %%
data.shape
# Out:
# (114000, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
data=data.drop(['Unnamed: 0', 'track_id','duration_ms', 'explicit', 'danceability', 'energy',
1
# Out:
#   Cell In[1], line 2
#     1
#      ^
# SyntaxError: incomplete input

# %%
data.head()
# Out:
#                   artists                  track_name  popularity  \
# 0             Gen Hoshino                      Comedy          73
# 1            Ben Woodward            Ghost - Acoustic          55
# 2  Ingrid Michaelson;ZAYN              To Begin Again          57
# 3            Kina Grannis  Can't Help Falling In Love          71
# 4        Chord Overstreet                     Hold On          82
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1430        0.0322          0.000001    0.3580    0.715   87.917
# 1       0.0763        0.9240          0.000006    0.1010    0.267   77.489
# 2       0.0557        0.2100          0.000000    0.1170    0.120   76.332
# 3       0.0363        0.9050          0.000071    0.1320    0.143  181.740
# 4       0.0526        0.4690          0.000000    0.0829    0.167  119.949
#
#    time_signature track_genre
# 0               4    acoustic
# 1               4    acoustic
# ...

# %%
data.tail()
# Out:
#                  artists           track_name  popularity  speechiness  \
# 113995     Rainy Lullaby  Sleep My Little Boy          21       0.0422
# 113996     Rainy Lullaby     Water Into Light          22       0.0401
# 113997     Cesária Evora       Miss Perfumado          22       0.0420
# 113998  Michael W. Smith              Friends          41       0.0297
# 113999     Cesária Evora            Barbincor          22       0.0725
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 113995         0.640             0.928    0.0863   0.0339  125.995
# 113996         0.994             0.976    0.1050   0.0350   85.239
# 113997         0.867             0.000    0.0839   0.7430  132.378
# 113998         0.381             0.000    0.2700   0.4130  135.960
# 113999         0.681             0.000    0.0893   0.7080   79.198
#
#         time_signature  track_genre
# 113995               5  world-music
# 113996               4  world-music
# ...

# %%
# In Top 50 most popular songs
popsongs=data.sort_values('popularity',ascending=False)
popsongs.head(50)
# Out:
#                           artists                             track_name  \
# 20001        Sam Smith;Kim Petras              Unholy (feat. Kim Petras)
# 81051        Sam Smith;Kim Petras              Unholy (feat. Kim Petras)
# 51664            Bizarrap;Quevedo  Quevedo: Bzrp Music Sessions, Vol. 52
# 81210     David Guetta;Bebe Rexha                        I'm Good (Blue)
# 89411               Manuel Turizo                             La Bachata
# 68303               Manuel Turizo                             La Bachata
# 88410               Manuel Turizo                             La Bachata
# 30003     David Guetta;Bebe Rexha                        I'm Good (Blue)
# 20008     David Guetta;Bebe Rexha                        I'm Good (Blue)
# 67356               Manuel Turizo                             La Bachata
# 68305  Bad Bunny;Chencho Corleone                        Me Porto Bonito
# 68304                   Bad Bunny                       Tití Me Preguntó
# ...

# %%
# In Top 50 'POP' Genre songs
cond=popsongs['track_genre']=='pop'
popsongs.where(cond).head(50).dropna()
# Out:
#                        artists                 track_name  popularity  \
# 81051     Sam Smith;Kim Petras  Unholy (feat. Kim Petras)       100.0
# 81210  David Guetta;Bebe Rexha            I'm Good (Blue)        98.0
# 81174              OneRepublic            I Ain't Worried        96.0
# 81003              Chris Brown        Under The Influence        96.0
# 81052             Harry Styles                  As It Was        95.0
# 81102                     Joji              Glimpse of Us        94.0
# 81853        The Neighbourhood            Sweater Weather        93.0
# 81861                Tom Odell               Another Love        93.0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 81051       0.0864       0.01300          0.000005    0.2660    0.238
# 81210       0.0343       0.00383          0.000007    0.3710    0.304
# 81174       0.0475       0.08260          0.000745    0.0546    0.825
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artists           113999 non-null  object
#  1   track_name        113999 non-null  object
#  2   popularity        114000 non-null  float64
#  3   speechiness       114000 non-null  float64
#  4   acousticness      114000 non-null  float64
#  5   instrumentalness  114000 non-null  float64
#  6   liveness          114000 non-null  float64
#  7   valence           114000 non-null  float64
#  8   tempo             114000 non-null  float64
#  9   time_signature    114000 non-null  int64
#  10  track_genre       114000 non-null  object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 9.6+ MB

# %%
data['popularity'].describe()
# Out:
# count    114000.000000
# mean         33.238535
# std          22.305078
# min           0.000000
# 25%          17.000000
# 50%          35.000000
# 75%          50.000000
# max         100.000000
# Name: popularity, dtype: float64

# %%
data['popularity'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['tempo'].plot(kind="line")
# Out:
# <Axes: >

# %%
plt.boxplot(data["popularity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16c52f210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16c541150>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16c440ed0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16c542010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16c543190>],
#  'means': []}

# %%
plt.violinplot(data["liveness"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x16c571b50>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x16c48d050>,
#  'cmins': <matplotlib.collections.LineCollection at 0x16c5b5610>,
#  'cbars': <matplotlib.collections.LineCollection at 0x16c5b7090>}

# %%
sns.countplot(x='popularity',data=data)
# Out:
# <Axes: xlabel='popularity', ylabel='count'>

# %%
g = data['popularity'].value_counts()
plt.bar(g.index, g.values)
plt.title("Popularity Distribution")
plt.xlabel("Popularity")
plt.ylabel("Count")
plt.show()

# %%
dependents = data['popularity'].value_counts()
plt.pie(dependents.values, labels=dependents.index, autopct='%1.1f%%')
plt.title("Popularity Distribution")
# Out:
# Text(0.5, 1.0, 'Popularity Distribution')

# %%
sns.distplot(data['tempo'])
# Out:
# /var/folders/df/cjrh6jqs3w90375f4bscv80r0000gn/T/ipykernel_9310/1786253841.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['tempo'])
# <Axes: xlabel='tempo', ylabel='Density'>

# %%
sns.kdeplot(data['liveness'], shade=True, color="r")
# Out:
# /var/folders/df/cjrh6jqs3w90375f4bscv80r0000gn/T/ipykernel_9310/2280740929.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data['liveness'], shade=True, color="r")
# <Axes: xlabel='liveness', ylabel='Density'>

# %%
data['popularity'] = np.log1p(data['popularity'])
sns.distplot(data['popularity'])
# Out:
# /var/folders/df/cjrh6jqs3w90375f4bscv80r0000gn/T/ipykernel_9310/225930898.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['popularity'])
# <Axes: xlabel='popularity', ylabel='Density'>

# %%
data['acousticness'] = np.log1p(data['acousticness'])
sns.distplot(data['acousticness'])
data['acousticness'].kurt()
# Out:
# /var/folders/df/cjrh6jqs3w90375f4bscv80r0000gn/T/ipykernel_9310/545318611.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['acousticness'])
# -1.2206242219406926

# %%
var = 'liveness'
data2 = pd.concat([data['popularity'], data[var]], axis=1)
data2.plot.scatter(x=var, y='popularity')
# Out:
# <Axes: xlabel='liveness', ylabel='popularity'>

# %%
sns.jointplot(data,x="popularity",y="acousticness",kind="scatter")
plt.suptitle("Joint Plot of Popularity & Acousticness of the Songs")
# Out:
# Text(0.5, 0.98, 'Joint Plot of Popularity & Acousticness of the Songs')

# %%
datas=data.drop(['artists','track_name','track_genre'],axis=1)

# %%
corrmat = datas.corr(method='spearman')
f, ax = plt.subplots(figsize=(12, 10))
sns.heatmap(corrmat, ax=ax, cmap="YlGnBu", linewidths=0.1)
# Out:
# <Axes: >

# %%
datas.cov()
# Out:
#                   popularity   speechiness  acousticness  instrumentalness  \
# popularity          1.942259  1.039961e-03 -3.383826e-03         -0.001169
# speechiness         0.001040  1.117933e-02 -8.620369e-07         -0.002933
# acousticness       -0.003384 -8.620369e-07  5.733617e-02          0.005828
# instrumentalness   -0.001169 -2.933121e-03  5.827693e-03          0.095824
# liveness            0.013281  4.130872e-03 -8.298645e-04         -0.004708
# valence            -0.020570  1.004238e-03 -5.329865e-03         -0.026028
# tempo               1.472273  5.475034e-02 -1.495126e+00         -0.467061
# time_signature      0.011349 -5.087031e-07 -1.751316e-02         -0.011059
#
#                   liveness   valence       tempo  time_signature
# popularity        0.013281 -0.020570    1.472273    1.134889e-02
# speechiness       0.004131  0.001004    0.054750   -5.087031e-07
# acousticness     -0.000830 -0.005330   -1.495126   -1.751316e-02
# ...

# %%
def mean(values):
    return sum(values)/float(len(values))

# %%
def variance(values,mean):
    return sum([(x-mean)**2 for x in values])

# %%
def covariance(x,mean_x,y,mean_y):
    covar=0.0
    for i in range(len(x)):
        covar+=(x[i]-mean_x) * (y[i]-mean_y)
    return covar

# %%
def coefficients(dataset):
    b1=covariance(x,mean_x,y,mean_y)/variance(x,mean_x)
    b0=mean_y-b1*mean_x
    return[b0,b1]

# %%
def simple_linear_regression(train,test):
    for row in test:
        ytest = b0 + b1 * row[0]
    return ytest

# %%
dataset=[[30,18],[40,70],[18,45],[60,70],[15,30],[90,68],[75,90]]
x=[row[0] for row in dataset]
y=[row[1] for row in dataset]
mean_x=mean(x)
mean_y=mean(y)

# %%
variance_x=variance(x,mean_x)
variance_y=variance(y,mean_y)
print('x stats:mean=%.3f variance=%.3f' % (mean_x,variance_x))
print('y stats:mean=%.3f variance=%.3f' % (mean_y,variance_y))
# Out:
# x stats:mean=46.857 variance=5004.857
# y stats:mean=55.857 variance=3932.857

# %%
covar = covariance(x,mean_x,y,mean_y)
print('covariance: %.3f' % (covar))
# Out:
# covariance: 3348.857

# %%
b0,b1 = coefficients(dataset)
print('coefficients:b0=%.3f,b1=%.3f' % (b0,b1))
print('Regression equation of y on x : y=%.3f+%.3fx '% (b0, b1))
# Out:
# coefficients:b0=24.504,b1=0.669
# Regression equation of y on x : y=24.504+0.669x

# %%
test=[[55]]
result=simple_linear_regression(dataset,test)
print('Value of y when x=55 is %.3f' % (result))
# Out:
# Value of y when x=55 is 61.306

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
dataset=[[30,18],[40,70],[18,45],[60,70],[15,30],[90,68],[75,90]]
x=np.array([row[0] for row in dataset]).reshape(-1,1)
y=np.array([row[1] for row in dataset])
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.5697618758642036

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.5697618758642036
# intercept: 24.504024661757153
# slope: [0.66912142]

# %%
y_pred = model.predict([[55]])
print('predicted response:', y_pred)
# Out:
# predicted response: [61.30570303]

# %%
sns.regplot(x='popularity',y='time_signature',data=data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.regplot(x='popularity',y='time_signature',data=data)
#
# NameError: name 'sns' is not defined

# %%
import numpy as np
from sklearn.neighbors import KNeighborsRegressor

dataset = np.array([[30, 18], [40, 70], [18, 45], [60, 70], [15, 30], [90, 68], [75, 90]])
x = dataset[:, 0].reshape(-1, 1)
y = dataset[:, 1]

k = 3
knn_model = KNeighborsRegressor(n_neighbors=k)

knn_model.fit(x, y)

new_x = np.array([[25]])  
predicted_y = knn_model.predict(new_x)

print(f"Predicted y for x={new_x}: {predicted_y}")

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
y_pred = model.predict([[55]])
print('predicted response:', y_pred)
# Out:
# coefficient of determination: -13727.323214591539
# coefficient of determination: -13727.323214591539
# intercept: 24.504024661757153
# slope: [0.66912142]
# predicted response: [61.30570303]

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

dataset = np.array([[30, 0], [40, 1], [18, 0], [60, 1], [15, 0], [90, 1], [75, 1]])

x = dataset[:, 0].reshape(-1, 1)
y = dataset[:, 1]

logistic_model = LogisticRegression()
logistic_model.fit(x, y)

predicted_probs = logistic_model.predict_proba(x)
predicted_labels = logistic_model.predict(x)

print("Predicted Probabilities:")
print(predicted_probs)

print("Predicted Class Labels:")
print(predicted_labels)

x_range = np.linspace(0, 100, 100).reshape(-1, 1)
y_prob = logistic_model.predict_proba(x_range)[:, 1]

plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=y, cmap=plt.cm.coolwarm, marker='o', edgecolors='k')
plt.plot(x_range, y_prob, color='blue', linewidth=2)
plt.xlabel("Popularity")
plt.ylabel("Class (0 or 1)")
plt.title("Logistic Regression Decision Boundary")
plt.show()
# Out:
# Predicted Probabilities:
# [[9.43784753e-01 5.62152467e-02]
#  [5.62957199e-02 9.43704280e-01]
#  [9.99931499e-01 6.85008804e-05]
#  [7.53148053e-07 9.99999247e-01]
#  [9.99987384e-01 1.26155622e-05]
#  [3.37507799e-14 1.00000000e+00]
#  [1.59518621e-10 1.00000000e+00]]
# Predicted Class Labels:
# [0 1 0 1 0 1 1]
